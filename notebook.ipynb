# %%
import joblib
import pandas as pd

# %%
model = joblib.load("heart_disease_pipeline.pkl")

model
# Out:
# c:\Users\Walter\Documents\Comunidados\Live_13_deploy\.venv\Lib\site-packages\sklearn\base.py:525: InconsistentVersionWarning: Trying to unpickle estimator SimpleImputer from version 1.8.0 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Walter\Documents\Comunidados\Live_13_deploy\.venv\Lib\site-packages\sklearn\base.py:525: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
df = pd.DataFrame([
    {
        "age": 45,
        "sex": "Male",
        "resting_bp_systolic": 125,
        "resting_bp_diastolic": 80,
        "cholesterol_total": 210,
        "hdl": 52,
        "ldl": 130,
        "triglycerides": 150,
        "fasting_blood_sugar": 95,
        "hba1c": 5.5,
        "bmi": 26.3,
        "resting_heart_rate": 72,
        "max_heart_rate_achieved": 165,
        "chest_pain_type": "Typical Angina",
        "exercise_induced_angina": False,
        "st_depression": 0.8,
        "family_history": True,
        "smoker_status": "Former",
        "alcohol_units_per_week": 3,
        "exercise_minutes_per_week": 180,
        "sleep_hours": 7.5,
        "stress_score": 4.2,
        "wearable_owner": True,
        "daily_steps": 9500,
        "diet_quality_score": 7.8
    },
    {
        "age": 62,
        "sex": "Female",
        "resting_bp_systolic": 145,
        "resting_bp_diastolic": 90,
        "cholesterol_total": 260,
        "hdl": 42,
        "ldl": 170,
        "triglycerides": 220,
        "fasting_blood_sugar": 135,
        "hba1c": 6.8,
        "bmi": 31.4,
        "resting_heart_rate": 85,
        "max_heart_rate_achieved": 140,
        "chest_pain_type": "Atypical Angina",
        "exercise_induced_angina": True,
        "st_depression": 2.1,
        "family_history": True,
        "smoker_status": "Current",
        "alcohol_units_per_week": 6,
        "exercise_minutes_per_week": 30,
        "sleep_hours": 5.8,
        "stress_score": 8.1,
        "wearable_owner": False,
        "daily_steps": 3200,
        "diet_quality_score": 3.5
    },
    {
        "age": 34,
        "sex": "Male",
        "resting_bp_systolic": 118,
        "resting_bp_diastolic": 76,
        "cholesterol_total": 180,
        "hdl": 61,
        "ldl": 95,
        "triglycerides": 90,
        "fasting_blood_sugar": 88,
        "hba1c": 5.1,
        "bmi": 23.4,
        "resting_heart_rate": 65,
        "max_heart_rate_achieved": 182,
        "chest_pain_type": "Non-anginal Pain",
        "exercise_induced_angina": False,
        "st_depression": 0.2,
        "family_history": False,
        "smoker_status": "Never",
        "alcohol_units_per_week": 1,
        "exercise_minutes_per_week": 300,
        "sleep_hours": 8.2,
        "stress_score": 2.8,
        "wearable_owner": True,
        "daily_steps": 14500,
        "diet_quality_score": 9.3
    },
    {
        "age": 57,
        "sex": "Male",
        "resting_bp_systolic": 138,
        "resting_bp_diastolic": 86,
        "cholesterol_total": 235,
        "hdl": 47,
        "ldl": 150,
        "triglycerides": 185,
        "fasting_blood_sugar": 112,
        "hba1c": 6.1,
        "bmi": 28.9,
        "resting_heart_rate": 79,
        "max_heart_rate_achieved": 150,
        "chest_pain_type": "Asymptomatic",
        "exercise_induced_angina": True,
        "st_depression": 1.4,
        "family_history": True,
        "smoker_status": "Former",
        "alcohol_units_per_week": 4,
        "exercise_minutes_per_week": 90,
        "sleep_hours": 6.4,
        "stress_score": 6.5,
        "wearable_owner": False,
        "daily_steps": 5400,
        "diet_quality_score": 5.6
    },
    {
        "age": 41,
        "sex": "Female",
        "resting_bp_systolic": 122,
        "resting_bp_diastolic": 78,
        "cholesterol_total": 195,
        "hdl": 58,
        "ldl": 110,
        "triglycerides": 115,
        "fasting_blood_sugar": 92,
        "hba1c": 5.3,
        "bmi": 24.8,
        "resting_heart_rate": 70,
        "max_heart_rate_achieved": 170,
        "chest_pain_type": "Typical Angina",
        "exercise_induced_angina": False,
        "st_depression": 0.4,
        "family_history": False,
        "smoker_status": "Never",
        "alcohol_units_per_week": 2,
        "exercise_minutes_per_week": 240,
        "sleep_hours": 7.9,
        "stress_score": 3.7,
        "wearable_owner": True,
        "daily_steps": 11000,
        "diet_quality_score": 8.5
    }
])

df
# Out:
#    age     sex  resting_bp_systolic  resting_bp_diastolic  cholesterol_total  \
# 0   45    Male                  125                    80                210
# 1   62  Female                  145                    90                260
# 2   34    Male                  118                    76                180
# 3   57    Male                  138                    86                235
# 4   41  Female                  122                    78                195
#
#    hdl  ldl  triglycerides  fasting_blood_sugar  hba1c  ...  st_depression  \
# 0   52  130            150                   95    5.5  ...            0.8
# 1   42  170            220                  135    6.8  ...            2.1
# 2   61   95             90                   88    5.1  ...            0.2
# 3   47  150            185                  112    6.1  ...            1.4
# 4   58  110            115                   92    5.3  ...            0.4
#
# ...

# %%
prediction = model.predict(df)
probability = model.predict_proba(df)

prediction
# Out:
# array([1, 1, 0, 1, 0])

# %%
resultado = df.copy()

resultado["prediction"] = prediction
resultado["probability_heart_disease"] = probability[:, 1]

resultado
# Out:
#    age     sex  resting_bp_systolic  resting_bp_diastolic  cholesterol_total  \
# 0   45    Male                  125                    80                210
# 1   62  Female                  145                    90                260
# 2   34    Male                  118                    76                180
# 3   57    Male                  138                    86                235
# 4   41  Female                  122                    78                195
#
#    hdl  ldl  triglycerides  fasting_blood_sugar  hba1c  ...  smoker_status  \
# 0   52  130            150                   95    5.5  ...         Former
# 1   42  170            220                  135    6.8  ...        Current
# 2   61   95             90                   88    5.1  ...          Never
# 3   47  150            185                  112    6.1  ...         Former
# 4   58  110            115                   92    5.3  ...          Never
#
# ...

# %%
resultado[
    [
        "age",
        "sex",
        "prediction",
        "probability_heart_disease"
    ]
]
# Out:
#    age     sex  prediction  probability_heart_disease
# 0   45    Male           1                   0.700503
# 1   62  Female           1                   0.999851
# 2   34    Male           0                   0.009797
# 3   57    Male           1                   0.993088
# 4   41  Female           0                   0.087968
